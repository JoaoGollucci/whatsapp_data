# %%
import subprocess, shlex, requests

SERVICE_URL = "https://waha-meli-teste-180862637961.us-central1.run.app"  # audience
# ENDPOINT = f"{SERVICE_URL}/api/default/chats"
ENDPOINT = f"{SERVICE_URL}/api/default/chats/160022042530040@lid/messages"


cmd = f'gcloud auth print-identity-token'
token = """eyJhbGciOiJSUzI1NiIsImtpZCI6IjRmZWI0NGYwZjdhN2UyN2M3YzQwMzM3OWFmZjIwYWY1YzhjZjUyZGMiLCJ0eXAiOiJKV1QifQ..EJY9qQZ1WSllBa8hAQdSYwPkBfUSW9_5HWYUZeJWtQ7GFbVTo7de-zwIruGE0bKvyClhq9XOXwraJzB53Edu0mus-X4C5AaGro3ku_0dXDRjlK6_Q-IngMuI2vUPm1dQOtsL95SxjWTay38WMD-fSnwn-fH8E2CchJbwctYjr60NuMR0zAbYQDWduR2fkVehMTK-A7QvB8HgkOLnL640KkD5AtBcD6yYft0cqDMLvBEmsV3bVVOyVETKtCgfOYOGk8hfgHfUpZ50auNwZ1ClKXR_ImQwOLY9XrgZ3qYCC87TBQMR0K6rJQFHWmYz93loIFJP8HwzBK1u0mikofJLVQ"""

r = requests.get(ENDPOINT, headers={"Authorization": f"Bearer {token}"}, timeout=30)
r.raise_for_status()
print(r.status_code, r.text)
# Out:
# 200 [{"id":"true_160022042530040@lid_AC6E1963D13E46D831646F899DE4CAEC","timestamp":1762790111,"from":"160022042530040@lid","fromMe":true,"source":"app","body":"Teste","to":null,"participant":null,"hasMedia":false,"media":null,"ack":2,"ackName":"DEVICE","replyTo":null,"_data":{"Info":{"Chat":"160022042530040@lid","Sender":"118258317394134@lid","IsFromMe":true,"IsGroup":false,"AddressingMode":"","SenderAlt":"","RecipientAlt":"5511995020957@s.whatsapp.net","BroadcastListOwner":"","BroadcastRecipients":null,"ID":"AC6E1963D13E46D831646F899DE4CAEC","ServerID":0,"Type":"text","PushName":"João Gauge","Timestamp":"2025-11-10T15:55:11Z","Category":"","Multicast":false,"MediaType":"","Edit":"","MsgBotInfo":{"EditType":"","EditTargetID":"","EditSenderTimestampMS":"0001-01-01T00:00:00Z"},"MsgMetaInfo":{"TargetID":"","TargetSender":"","TargetChat":"","DeprecatedLIDSession":null,"ThreadMessageID":"","ThreadMessageSenderJID":""},"VerifiedName":null,"DeviceSentMeta":{"DestinationJID":"160022042530040
# ...

# %%
import requests

SERVICE_URL = "https://waha-meli-teste-180862637961.us-central1.run.app"  # audience
# ENDPOINT = f"{SERVICE_URL}/api/sessions"
ENDPOINT = f"{SERVICE_URL}/api/default/chats"


teste = requests.get(ENDPOINT, )
print(teste.status_code, teste.text)
# Out:
# 422 {"error":"Session status is not as expected. Try again later or restart the session","session":"default","status":"FAILED","expected":["WORKING"]}
